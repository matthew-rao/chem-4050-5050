# %%
#Task Part 1

#Create dictionaries storing cartesian coordinates of H2, H2O, and Benzene

hydrogen = {
    "H1": [0.0000, 0.0000, 0.0000],
    "H2": [0.0000, 0.0000, 0.7414]
}

water = {
    "O1": [0.0000, 0.0000, 0.1173],
    "H1": [0.0000, 0.7572, -0.4692],
    "H2": [0.0000, -0.7572, -0.4692]
}

benzene = {
    "C1": [0.0000, 1.3970, 0.0000],
    "C2": [1.2098, 0.6985, 0.0000],
    "C3": [1.2098, -0.6985, 0.0000],
    "C4": [0.0000, -1.3970, 0.0000],
    "C5": [-1.2098, -0.6985, 0.0000],
    "C6": [-1.2098, 0.6985, 0.0000],
    "H7": [0.0000, 2.4810, 0.0000],
    "H8": [2.1486, 1.2405, 0.0000],
    "H9": [2.1486, -1.2405, 0.0000],
    "H10": [0.0000, -2.4810, 0.0000],
    "H11": [-2.1486, -1.2405, 0.0000],
    "H12": [-2.1486, 1.2405, 0.0000]
}

#Print coordinates to verify correct storage
print(hydrogen)
print(water)
print(benzene)
# Out:
# {'H1': [0.0, 0.0, 0.0], 'H2': [0.0, 0.0, 0.7414]}
# {'O1': [0.0, 0.0, 0.1173], 'H1': [0.0, 0.7572, -0.4692], 'H2': [0.0, -0.7572, -0.4692]}
# {'C1': [0.0, 1.397, 0.0], 'C2': [1.2098, 0.6985, 0.0], 'C3': [1.2098, -0.6985, 0.0], 'C4': [0.0, -1.397, 0.0], 'C5': [-1.2098, -0.6985, 0.0], 'C6': [-1.2098, 0.6985, 0.0], 'H7': [0.0, 2.481, 0.0], 'H8': [2.1486, 1.2405, 0.0], 'H9': [2.1486, -1.2405, 0.0], 'H10': [0.0, -2.481, 0.0], 'H11': [-2.1486, -1.2405, 0.0], 'H12': [-2.1486, 1.2405, 0.0]}

# %%
#Part 2 and 3: Bond Length and Angle Calculation

#Import NumPy
import numpy as np

#Define bond length and bond angle functions
def compute_bond_length(coord1, coord2):
    """Takes the coordinates of 2 atoms and returns the bond length between the atoms,
        where coord1 and coord2 represent 2 lists of Cartesian coordinates.

        If the bond length returned is greater than 2 angstroms, a string warning will be printed
        alongside the float or integer bond length
    """
    
    array1 = np.array(coord1)                               #Convert to numpy
    array2 = np.array(coord2)

    coordinate_difference = array1 - array2
    squared_difference = coordinate_difference ** 2
    bond_length = np.sqrt(np.sum(squared_difference))       #Use distance formula to calculate Euclidian distance

    if bond_length < 2:
        print(f"Bond length: {bond_length} angstroms")
    else:
        print(f"The bond length is: {bond_length} angstroms, which does not fall in the covalent bond length range.")

    return bond_length

def compute_bond_angle(coord1, coord2, coord3):
    """Takes the Cartesian coordinates of 3 atoms and returns the bond angle in degrees,
        where coord1, coord2, and coord3 represent lists of float or integer values.
        
        Function will also print the classification of the angle as right, obtuse or acute.
        """
    
    a = np.array(coord1)                                    #Convert to numpy
    b = np.array(coord2)
    c = np.array(coord3)

    ab = b - a
    bc = c - b                                              #Find vectors AB and BC
    numerator = np.dot(ab, bc)                              #Dot product between given vectors             

    ab_magnitude = np.linalg.norm(ab)                       
    bc_magnitude = np.linalg.norm(bc)
    denominator = ab_magnitude * bc_magnitude               #Find product of the magnitude of the vectors

    bond_angle = np.degrees(np.arccos(numerator / denominator))

    if bond_angle > 90:
        print(f"Bond angle: {bond_angle}. It is obtuse")

    elif bond_angle < 90:
        print(f"Bond angle: {bond_angle}. It is acute")
    else:
        print(f"Bond angle: {bond_angle}. It is a right angle")

    return bond_angle

# %%
#Part 4: Automate Bond Angle and Length Calculations

#Create function to compute bond lengths

def calculate_all_bond_lengths(molecule):
    """Takes a dictionary as an input, where the keys in the dictionaries represent the atoms and the values
        represent cartesian coordinates. Iterates through all possible combinations of 2 unique atoms and 
        computes the bond length.
        
        Returns a list of calculated bond lengths and prints the list after iterating through.
        """
    
    bond_lengths = []
    checked_atoms = []

    for atom1, coordinate1 in molecule.items():
        for atom2, coordinate2 in molecule.items():         # Nested for loop to avoid calculating duplicates
            if atom1 != atom2 and sorted((atom1, atom2)) not in checked_atoms:
                length = compute_bond_length(coordinate1, coordinate2)
                bond_lengths.append(length)
                checked_atoms.append(sorted((atom1, atom2)))  #Ensure no duplicates

    return bond_lengths                                     # Print and return given result


#Create function to compute bond angles

def calculate_all_bond_angles(molecule):
    """Takes a dictionary as an input, where the keys in the dictionaries represent the atoms and the values
        represent cartesian coordinates. Iterates through all possible combinations of 3 unique atoms and
        computes the bond angle.
        
        Returns a list of calculated bond angles and prints the list after iterating through.
        """
    bond_angles = []
    checked_atoms = []
    for atom1, coordinate1 in molecule.items():
        for atom2, coordinate2 in molecule.items():
            for atom3, coordinate3 in molecule.items():     # Nested for loop to avoid calculating duplicates
                if atom1 != atom2 and atom1 != atom3 and atom2 != atom3 and sorted((atom1, atom2, atom3)) not in checked_atoms:
                    angle = compute_bond_angle(coordinate1, coordinate2, coordinate3)
                    bond_angles.append(angle)
                    checked_atoms.append(sorted((atom1, atom2, atom3)))   # Ensures no duplictates

    return bond_angles


#Call functions on each unique molecule
hydrogen_lengths = calculate_all_bond_lengths(hydrogen)
water_lengths = calculate_all_bond_lengths(water)
benzene_lengths = calculate_all_bond_lengths(benzene)

hydrogen_angles = calculate_all_bond_angles(hydrogen)
water_angles = calculate_all_bond_angles(water)
benzene_angles = calculate_all_bond_angles(benzene)
# Out:
# Bond length: 0.7414 angstroms
# Bond length: 0.9577755948028744 angstroms
# Bond length: 0.9577755948028744 angstroms
# Bond length: 1.5144 angstroms
# Bond length: 1.3969675336241714 angstroms
# The bond length is: 2.4196562338481056 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.794 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.4196562338481056 angstroms, which does not fall in the covalent bond length range.
# Bond length: 1.3969675336241714 angstroms
# Bond length: 1.0839999999999999 angstroms
# The bond length is: 2.1542920438046465 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.4018947970212134 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.878 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.4018947970212134 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.1542920438046465 angstroms, which does not fall in the covalent bond length range.
# Bond length: 1.397 angstroms
# The bond length is: 2.4196562338481056 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.7939350672483427 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.4196 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.1542799934084704 angstroms, which does not fall in the covalent bond length range.
# Bond length: 1.0840246491662446 angstroms
# The bond length is: 2.154313449802512 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.401887165971264 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.8779597161394035 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.401854576550855 angstroms, which does not fall in the covalent bond length range.
# Bond length: 1.3969675336241714 angstroms
# The bond length is: 2.4196 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.7939350672483427 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.401887165971264 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.154313449802512 angstroms, which does not fall in the covalent bond length range.
# Bond length: 1.0840246491662446 angstroms
# The bond length is: 2.1542799934084704 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.401854576550855 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.8779597161394035 angstroms, which does not fall in the covalent bond length range.
# Bond length: 1.3969675336241714 angstroms
# The bond length is: 2.4196562338481056 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.878 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.4018947970212134 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.1542920438046465 angstroms, which does not fall in the covalent bond length range.
# Bond length: 1.0839999999999999 angstroms
# The bond length is: 2.1542920438046465 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.4018947970212134 angstroms, which does not fall in the covalent bond length range.
# Bond length: 1.397 angstroms
# The bond length is: 3.401887165971264 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.8779597161394035 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.401854576550855 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.1542799934084704 angstroms, which does not fall in the covalent bond length range.
# Bond length: 1.0840246491662446 angstroms
# The bond length is: 2.154313449802512 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.1542799934084704 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.401854576550855 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.8779597161394035 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 3.401887165971264 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.154313449802512 angstroms, which does not fall in the covalent bond length range.
# Bond length: 1.0840246491662446 angstroms
# The bond length is: 2.4809921825753505 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 4.297213540190899 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 4.962 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 4.297213540190899 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.4809921825753505 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.481 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 4.297213540190899 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 4.961984365150701 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 4.2972 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.4809921825753505 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 4.2972 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 4.961984365150701 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.4809921825753505 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 4.297213540190899 angstroms, which does not fall in the covalent bond length range.
# The bond length is: 2.481 angstroms, which does not fall in the covalent bond length range.
# Bond angle: 142.23991940918322. It is obtuse
# Bond angle: 59.999231203874366. It is acute
# Bond angle: 89.9984624196601. It is acute
# Bond angle: 119.99846240774873. It is obtuse
# Bond angle: 149.99923120387436. It is obtuse
# Bond angle: 154.16588668179713. It is obtuse
# Bond angle: 60.0000166132611. It is acute
# Bond angle: 34.164492752945804. It is acute
# Bond angle: 80.8310551037146. It is acute
# Bond angle: 119.99888757428906. It is obtuse
# Bond angle: 159.16694199840674. It is obtuse
# Bond angle: 89.9984624196601. It is acute
# Bond angle: 119.99923121578576. It is obtuse
# Bond angle: 150.0000000119114. It is obtuse
# Bond angle: 170.83259268405445. It is obtuse
# Bond angle: 124.16603033328568. It is obtuse
# Bond angle: 30.00152096707883. It is acute
# Bond angle: 64.16434910145726. It is acute
# Bond angle: 110.83152042125336. It is obtuse
# Bond angle: 149.99957484537106. It is obtuse
# Bond angle: 120.00076879612564. It is obtuse
# Bond angle: 150.00076878421427. It is obtuse
# Bond angle: 180.0. It is obtuse
# Bond angle: 140.83253189664. It is obtuse
# Bond angle: 94.16596031582208. It is obtuse
# Bond angle: 0.0. It is acute
# Bond angle: 94.16596031582208. It is obtuse
# Bond angle: 140.83253189664. It is obtuse
# Bond angle: 150.00076878421427. It is obtuse
# Bond angle: 170.83259268405445. It is obtuse
# Bond angle: 149.99957484537106. It is obtuse
# Bond angle: 110.83152042125336. It is obtuse
# Bond angle: 64.16434910145726. It is acute
# Bond angle: 30.00152096707883. It is acute
# Bond angle: 124.16603033328568. It is obtuse
# Bond angle: 154.16588668179713. It is obtuse
# Bond angle: 159.16694199840674. It is obtuse
# Bond angle: 119.99888757428906. It is obtuse
# Bond angle: 80.8310551037146. It is acute
# Bond angle: 34.164492752945804. It is acute
# Bond angle: 60.0000166132611. It is acute
# Bond angle: 120.00010423187281. It is obtuse
# Bond angle: 150.0001042316539. It is obtuse
# Bond angle: 180.0. It is obtuse
# Bond angle: 150.0001042316539. It is obtuse
# Bond angle: 120.00010423187281. It is obtuse
# Bond angle: 85.83403968417792. It is acute
# Bond angle: 115.83393545252406. It is obtuse
# Bond angle: 145.8339354523051. It is obtuse
# Bond angle: 175.83403968417795. It is obtuse
# Bond angle: 99.16736387148718. It is obtuse
# Bond angle: 129.16746810336. It is obtuse
# Bond angle: 159.16757233523282. It is obtuse
# Bond angle: 120.00010423187281. It is obtuse
# Bond angle: 150.0001042316539. It is obtuse
# Bond angle: 140.83253189664. It is obtuse
# Bond angle: 59.999231203874366. It is acute
# Bond angle: 90.0. It is a right angle
# Bond angle: 120.00076879612564. It is obtuse
# Bond angle: 159.16817610015977. It is obtuse
# Bond angle: 154.16526154907146. It is obtuse
# Bond angle: 60.00075218286456. It is acute
# Bond angle: 34.16511788567151. It is acute
# Bond angle: 80.8322892054676. It is acute
# Bond angle: 120.0003436295853. It is obtuse
# Bond angle: 90.0015375803399. It is obtuse
# Bond angle: 120.00153756842849. It is obtuse
# Bond angle: 150.00076878421424. It is obtuse
# Bond angle: 170.8317631124257. It is obtuse
# Bond angle: 124.16519153160783. It is obtuse
# Bond angle: 29.99923121578575. It is acute
# Bond angle: 64.16672910003633. It is acute
# Bond angle: 110.83330068085426. It is obtuse
# Bond angle: 120.00076879612564. It is obtuse
# Bond angle: 140.83259269596587. It is obtuse
# Bond angle: 179.9995748327252. It is obtuse
# Bond angle: 140.83152040934198. It is obtuse
# Bond angle: 94.16434908954588. It is obtuse
# Bond angle: 0.0015209794795447804. It is acute
# Bond angle: 94.16603034519707. It is obtuse
# Bond angle: 124.16511788567152. It is obtuse
# Bond angle: 170.83228920546765. It is obtuse
# Bond angle: 149.9996563704147. It is obtuse
# Bond angle: 110.83182389984023. It is obtuse
# Bond angle: 64.16526154907143. It is acute
# Bond angle: 29.999247817135473. It is acute
# Bond angle: 154.16522211754432. It is obtuse
# Bond angle: 175.83477788267462. It is obtuse
# Bond angle: 145.8348821143285. It is obtuse
# Bond angle: 115.83498634598236. It is obtuse
# Bond angle: 85.8349863462013. It is acute
# Bond angle: 119.99924781713545. It is obtuse
# Bond angle: 149.99914358548156. It is obtuse
# Bond angle: 179.99914358502187. It is obtuse
# Bond angle: 150.00075218286457. It is obtuse
# Bond angle: 85.83463421905574. It is acute
# Bond angle: 115.83473845092857. It is obtuse
# Bond angle: 145.83484268280137. It is obtuse
# Bond angle: 99.16828033203258. It is obtuse
# Bond angle: 129.16828033181363. It is obtuse
# Bond angle: 120.0003436295853. It is obtuse
# Bond angle: 60.00153759225128. It is acute
# Bond angle: 90.0015375803399. It is obtuse
# Bond angle: 120.00076879612564. It is obtuse
# Bond angle: 159.1682368994856. It is obtuse
# Bond angle: 154.16519151969644. It is obtuse
# Bond angle: 59.999231203874366. It is acute
# Bond angle: 34.16672911194773. It is acute
# Bond angle: 80.83330069276565. It is acute
# Bond angle: 90.0. It is a right angle
# Bond angle: 110.83182389984023. It is obtuse
# Bond angle: 149.9996563704147. It is obtuse
# Bond angle: 170.83228920546765. It is obtuse
# Bond angle: 124.16511788567152. It is obtuse
# Bond angle: 29.999247817135473. It is acute
# Bond angle: 64.16526154907143. It is acute
# Bond angle: 94.16434908954588. It is obtuse
# Bond angle: 140.83152040934198. It is obtuse
# Bond angle: 179.9995748327252. It is obtuse
# Bond angle: 140.83259269596587. It is obtuse
# Bond angle: 94.16603034519707. It is obtuse
# Bond angle: 0.0015209794795447804. It is acute
# Bond angle: 140.83192813171303. It is obtuse
# Bond angle: 170.83192813149407. It is obtuse
# Bond angle: 159.16817610015977. It is obtuse
# Bond angle: 129.16828033181363. It is obtuse
# Bond angle: 99.16828033203258. It is obtuse
# Bond angle: 154.16526154907146. It is obtuse
# Bond angle: 175.83484268258243. It is obtuse
# Bond angle: 145.83484268280137. It is obtuse
# Bond angle: 115.83473845092857. It is obtuse
# Bond angle: 120.00064795099173. It is obtuse
# Bond angle: 150.00075218286457. It is obtuse
# Bond angle: 179.99914358502187. It is obtuse
# Bond angle: 85.8349863462013. It is acute
# Bond angle: 115.83498634598236. It is obtuse
# Bond angle: 99.1677107945324. It is obtuse
# Bond angle: 59.999231203874366. It is acute
# Bond angle: 80.8310551037146. It is acute
# Bond angle: 119.99888757428906. It is obtuse
# Bond angle: 159.16694199840674. It is obtuse
# Bond angle: 154.16588668179713. It is obtuse
# Bond angle: 60.0000166132611. It is acute
# Bond angle: 34.164492752945804. It is acute
# Bond angle: 64.16434910145726. It is acute
# Bond angle: 110.83152042125336. It is obtuse
# Bond angle: 149.99957484537106. It is obtuse
# Bond angle: 170.83259268405445. It is obtuse
# Bond angle: 124.16603033328568. It is obtuse
# Bond angle: 30.00152096707883. It is acute
# Bond angle: 120.00010423187281. It is obtuse
# Bond angle: 150.0001042316539. It is obtuse
# Bond angle: 180.0. It is obtuse
# Bond angle: 150.0001042316539. It is obtuse
# Bond angle: 120.00010423187281. It is obtuse
# Bond angle: 140.83253189664. It is obtuse
# Bond angle: 170.83242766498608. It is obtuse
# Bond angle: 159.16757233523282. It is obtuse
# Bond angle: 129.16746810336. It is obtuse
# Bond angle: 154.16585608394925. It is obtuse
# Bond angle: 175.83403968417795. It is obtuse
# Bond angle: 145.8339354523051. It is obtuse
# Bond angle: 120.00010423187281. It is obtuse
# Bond angle: 150.0001042316539. It is obtuse
# Bond angle: 85.83403968417792. It is acute
# Bond angle: 34.16511788567151. It is acute
# Bond angle: 80.8322892054676. It is acute
# Bond angle: 120.0003436295853. It is obtuse
# Bond angle: 159.16817610015977. It is obtuse
# Bond angle: 154.16526154907146. It is obtuse
# Bond angle: 60.00075218286456. It is acute
# Bond angle: 99.16828033203258. It is obtuse
# Bond angle: 129.16828033181363. It is obtuse
# Bond angle: 159.16817610015977. It is obtuse
# Bond angle: 170.83192813149407. It is obtuse
# Bond angle: 140.83192813171303. It is obtuse
# Bond angle: 120.0003436295853. It is obtuse
# Bond angle: 150.0002393979314. It is obtuse
# Bond angle: 179.99976059906837. It is obtuse
# Bond angle: 149.9996563704147. It is obtuse
# Bond angle: 140.8321849735948. It is obtuse
# Bond angle: 170.83228920546765. It is obtuse
# Bond angle: 159.16760656265959. It is obtuse
# Bond angle: 154.16522211754432. It is obtuse
# Bond angle: 175.83477788267462. It is obtuse
# Bond angle: 119.99924781713545. It is obtuse
# Bond angle: 85.8349863462013. It is acute
# Bond angle: 115.83498634598236. It is obtuse
# Bond angle: 145.8348821143285. It is obtuse
# Bond angle: 175.83477788267462. It is obtuse
# Bond angle: 154.16522211754432. It is obtuse
# Bond angle: 99.1677107945324. It is obtuse
# Bond angle: 129.16760656287852. It is obtuse
# Bond angle: 159.16760656265959. It is obtuse
# Bond angle: 170.83228920546765. It is obtuse
# Bond angle: 119.99955213854186. It is obtuse
# Bond angle: 149.9996563704147. It is obtuse
# Bond angle: 179.99976059906837. It is obtuse
# Bond angle: 140.83192813171303. It is obtuse
# Bond angle: 170.83192813149407. It is obtuse
# Bond angle: 154.16526154907146. It is obtuse
# Bond angle: 59.99989576812719. It is acute
# Bond angle: 89.99979153647332. It is acute
# Bond angle: 119.99979153625438. It is obtuse
# Bond angle: 149.99989576812717. It is obtuse
# Bond angle: 89.99979153647332. It is acute
# Bond angle: 119.99989576834615. It is obtuse
# Bond angle: 150.00000000021896. It is obtuse
# Bond angle: 120.00010423187281. It is obtuse
# Bond angle: 150.00010423165386. It is obtuse
# Bond angle: 150.00010423165386. It is obtuse
# Bond angle: 59.99989576812719. It is acute
# Bond angle: 90.0. It is a right angle
# Bond angle: 120.00010423187281. It is obtuse
# Bond angle: 90.00020846352668. It is obtuse
# Bond angle: 120.00020846330773. It is obtuse
# Bond angle: 120.00010423187281. It is obtuse
# Bond angle: 60.000208463745636. It is acute
# Bond angle: 90.00020846352668. It is obtuse
# Bond angle: 90.0. It is a right angle
# Bond angle: 59.99989576812719. It is acute

# %%
#Print bond angles and lengths

#Bond lengths
print(f"Hydrogen lengths: {hydrogen_lengths}")
print(f"Water lengths: {water_lengths}")
print(f"Benzene lengths: {benzene_lengths}")

#Bond angles
print(f"Hydrogen angles: {hydrogen_angles}")
print(f"Water angles: {water_angles}")
print(f"Benzene angles: {benzene_angles}")
# Out:
# Hydrogen lengths: [0.7414]
# Water lengths: [0.9577755948028744, 0.9577755948028744, 1.5144]
# Benzene lengths: [1.3969675336241714, 2.4196562338481056, 2.794, 2.4196562338481056, 1.3969675336241714, 1.0839999999999999, 2.1542920438046465, 3.4018947970212134, 3.878, 3.4018947970212134, 2.1542920438046465, 1.397, 2.4196562338481056, 2.7939350672483427, 2.4196, 2.1542799934084704, 1.0840246491662446, 2.154313449802512, 3.401887165971264, 3.8779597161394035, 3.401854576550855, 1.3969675336241714, 2.4196, 2.7939350672483427, 3.401887165971264, 2.154313449802512, 1.0840246491662446, 2.1542799934084704, 3.401854576550855, 3.8779597161394035, 1.3969675336241714, 2.4196562338481056, 3.878, 3.4018947970212134, 2.1542920438046465, 1.0839999999999999, 2.1542920438046465, 3.4018947970212134, 1.397, 3.401887165971264, 3.8779597161394035, 3.401854576550855, 2.1542799934084704, 1.0840246491662446, 2.154313449802512, 2.1542799934084704, 3.401854576550855, 3.8779597161394035, 3.401887165971264, 2.154313449802512, 1.0840246491662446, 2.4809921825753505, 4.297213540190899, 4.962, 4.297213540190899, 2.4809921825753505, 2.481, 4.297213540190899, 4.961984365150701, 4.2972, 2.4809921825753505, 4.2972, 4.961984365150701, 2.4809921825753505, 4.297213540190899, 2.481]
# Hydrogen angles: []
# Water angles: [142.23991940918322]
# Benzene angles: [59.999231203874366, 89.9984624196601, 119.99846240774873, 149.99923120387436, 154.16588668179713, 60.0000166132611, 34.164492752945804, 80.8310551037146, 119.99888757428906, 159.16694199840674, 89.9984624196601, 119.99923121578576, 150.0000000119114, 170.83259268405445, 124.16603033328568, 30.00152096707883, 64.16434910145726, 110.83152042125336, 149.99957484537106, 120.00076879612564, 150.00076878421427, 180.0, 140.83253189664, 94.16596031582208, 0.0, 94.16596031582208, 140.83253189664, 150.00076878421427, 170.83259268405445, 149.99957484537106, 110.83152042125336, 64.16434910145726, 30.00152096707883, 124.16603033328568, 154.16588668179713, 159.16694199840674, 119.99888757428906, 80.8310551037146, 34.164492752945804, 60.0000166132611, 120.00010423187281, 150.0001042316539, 180.0, 150.0001042316539, 120.00010423187281, 85.83403968417792, 115.83393545252406, 145.8339354523051, 175.83403968417795, 99.16736387148718, 129.16746810336, 159.16757233523282, 120.00010423187281, 150.0001042316539, 140.83253189664, 59.999231203874366, 90.0, 120.00076879612564, 159.16817610015977, 154.16526154907146, 60.00075218286456, 34.16511788567151, 80.8322892054676, 120.0003436295853, 90.0015375803399, 120.00153756842849, 150.00076878421424, 170.8317631124257, 124.16519153160783, 29.99923121578575, 64.16672910003633, 110.83330068085426, 120.00076879612564, 140.83259269596587, 179.9995748327252, 140.83152040934198, 94.16434908954588, 0.0015209794795447804, 94.16603034519707, 124.16511788567152, 170.83228920546765, 149.9996563704147, 110.83182389984023, 64.16526154907143, 29.999247817135473, 154.16522211754432, 175.83477788267462, 145.8348821143285, 115.83498634598236, 85.8349863462013, 119.99924781713545, 149.99914358548156, 179.99914358502187, 150.00075218286457, 85.83463421905574, 115.83473845092857, 145.83484268280137, 99.16828033203258, 129.16828033181363, 120.0003436295853, 60.00153759225128, 90.0015375803399, 120.00076879612564, 159.1682368994856, 154.16519151969644, 59.999231203874366, 34.16672911194773, 80.83330069276565, 90.0, 110.83182389984023, 149.9996563704147, 170.83228920546765, 124.16511788567152, 29.999247817135473, 64.16526154907143, 94.16434908954588, 140.83152040934198, 179.9995748327252, 140.83259269596587, 94.16603034519707, 0.0015209794795447804, 140.83192813171303, 170.83192813149407, 159.16817610015977, 129.16828033181363, 99.16828033203258, 154.16526154907146, 175.83484268258243, 145.83484268280137, 115.83473845092857, 120.00064795099173, 150.00075218286457, 179.99914358502187, 85.8349863462013, 115.83498634598236, 99.1677107945324, 59.999231203874366, 80.8310551037146, 119.99888757428906, 159.16694199840674, 154.16588668179713, 60.0000166132611, 34.164492752945804, 64.16434910145726, 110.83152042125336, 149.99957484537106, 170.83259268405445, 124.16603033328568, 30.00152096707883, 120.00010423187281, 150.0001042316539, 180.0, 150.0001042316539, 120.00010423187281, 140.83253189664, 170.83242766498608, 159.16757233523282, 129.16746810336, 154.16585608394925, 175.83403968417795, 145.8339354523051, 120.00010423187281, 150.0001042316539, 85.83403968417792, 34.16511788567151, 80.8322892054676, 120.0003436295853, 159.16817610015977, 154.16526154907146, 60.00075218286456, 99.16828033203258, 129.16828033181363, 159.16817610015977, 170.83192813149407, 140.83192813171303, 120.0003436295853, 150.0002393979314, 179.99976059906837, 149.9996563704147, 140.8321849735948, 170.83228920546765, 159.16760656265959, 154.16522211754432, 175.83477788267462, 119.99924781713545, 85.8349863462013, 115.83498634598236, 145.8348821143285, 175.83477788267462, 154.16522211754432, 99.1677107945324, 129.16760656287852, 159.16760656265959, 170.83228920546765, 119.99955213854186, 149.9996563704147, 179.99976059906837, 140.83192813171303, 170.83192813149407, 154.16526154907146, 59.99989576812719, 89.99979153647332, 119.99979153625438, 149.99989576812717, 89.99979153647332, 119.99989576834615, 150.00000000021896, 120.00010423187281, 150.00010 ...
